# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
bond = pd.read_csv(r"D:\Machine Learning\jamesbond.csv")
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               26 non-null     object
#  1   Year               26 non-null     int64
#  2   Actor              26 non-null     object
#  3   Director           26 non-null     object
#  4   Box Office         26 non-null     float64
#  5   Budget             26 non-null     float64
#  6   Bond Actor Salary  18 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# [for rows ],[for column]
#
# 8:10  if there is a : the it means from:to (exclusive) here we will get from 8th to 9th row
# 0,2 if there is a comma then it means select only those rows

# %%
bond.iloc[5:6,[0,1,2]]
# Out:
#                   Film  Year         Actor
# 5  You Only Live Twice  1967  Sean Connery

# %% [markdown]
# # Rows will always have :
#
# # Column will always have ,
#
# # VIP TIP

# %%
## 8th row and 10th row
bond.iloc[8:10,[0,2]]
# Out:
#                           Film        Actor
# 8             Live and Let Die  Roger Moore
# 9  The Man with the Golden Gun  Roger Moore

# %%
## get data where budget > 50

# %%
bond.iloc[:,0]
# Out:
# 0                              Dr. No
# 1               From Russia with Love
# 2                          Goldfinger
# 3                         Thunderball
# 4                       Casino Royale
# 5                 You Only Live Twice
# 6     On Her Majesty's Secret Service
# 7                Diamonds Are Forever
# 8                    Live and Let Die
# 9         The Man with the Golden Gun
# 10               The Spy Who Loved Me
# 11                          Moonraker
# 12                 For Your Eyes Only
# 13              Never Say Never Again
# 14                          Octopussy
# 15                   A View to a Kill
# 16               The Living Daylights
# 17                    Licence to Kill
# 18                          GoldenEye
# 19                Tomorrow Never Dies
# 20            The World Is Not Enough
# 21                    Die Another Day
# 22                      Casino Royale
# 23                  Quantum of Solace
# 24                            Skyfall
# 25                            Spectre
# Name: Film, dtype: object

# %%
mask = (bond.iloc[:,5]<20) &  (bond.iloc[:,1] > 1962)

# %%
mask=(bond.iloc[:,5]<20)
bond[mask]
# Out:
#                     Film  Year         Actor       Director  BoxOffice  \
# 0                 Dr. No  1962  Sean Connery  Terence Young      448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young      543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton      820.4
#
#    Budget  BondActorSalary        ROI         Remarks
# 0     7.0              0.6  63.114286  I have no clue
# 1    12.6              1.6  42.158730  I have no clue
# 2    18.6              3.2  43.107527  I have no clue

# %%
mask=(bond.iloc[:,1]>1900)
bond[mask]
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     BoxOffice  Budget  BondActorSalary        ROI         Remarks
# 0       448.8     7.0              0.6  63.114286  I have no clue
# 1       543.8    12.6              1.6  42.158730  I have no clue
# 2       820.4    18.6              3.2  43.107527  I have no clue
# 3       848.1    41.9              4.7  19.241050  I have no clue
# 4       315.0    85.0              NaN   2.705882  I have no clue
# 5       514.2    59.9              4.4   7.584307  I have no clue
# 6       291.5    37.3              0.6   6.815013  I have no clue
# 7       442.5    34.7              5.8  11.752161  I have no clue
# 8       460.3    30.8              NaN  13.944805  I have no clue
# 9       334.0    27.7              NaN  11.057762  I have no clue
# 10      533.0    45.1              NaN  10.818182       Enjoyable
# 11      535.0    91.5              NaN   4.846995       Enjoyable
# 12      449.4    60.2              NaN   6.465116       Enjoyable
# 13      380.0    86.0              NaN   3.418605  I have no clue
# 14      373.8    53.9              7.8   5.935065       Enjoyable
# 15      275.2    54.5              9.1   4.049541       Enjoyable
# 16      313.5    68.8              5.2   3.556686  I have no clue
# 17      250.9    56.7              7.9   3.425044  I have no clue
# 18      518.5    76.9              5.1   5.742523        The best
# 19      463.2   133.9             10.0   2.459298        The best
# 20      439.5   158.3             13.5   1.776374        The best
# 21      465.4   154.2             17.9   2.018158        The best
# 22      581.5   145.3              3.3   3.002065  I have no clue
# 23      514.2   181.4              8.1   1.834620  I have no clue
# 24      943.5   170.2             14.5   4.543478  I have no clue
# 25      726.7   206.3              NaN   2.522540  I have no clue

# %%
bond[mask]
#bond[bond['Budget']<20]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond['Actor'].unique()
#gives unique values
# Out:
# array(['Sean Connery', 'David Niven', 'George Lazenby', 'Roger Moore',
#        'Timothy Dalton', 'Pierce Brosnan', 'Daniel Craig'], dtype=object)

# %%
bond['Actor'].nunique()
#gives number of unique values
# Out:
# 7

# %%
vals = bond['Actor'].value_counts()
#gives count of unique values

# %%
vals
# Out:
# Sean Connery      7
# Roger Moore       7
# Pierce Brosnan    4
# Daniel Craig      4
# Timothy Dalton    2
# David Niven       1
# George Lazenby    1
# Name: Actor, dtype: int64

# %%
vals.index
# Out:
# Index(['Sean Connery', 'Roger Moore', 'Pierce Brosnan', 'Daniel Craig',
#        'Timothy Dalton', 'David Niven', 'George Lazenby'],
#       dtype='object')

# %%
plt.pie(vals, labels=vals.index, autopct='% 0d%%');

# (vals , label = labelname , autopct gives the percentage in the pie )

# %%
# Top 2 Film that has earned the most
bond.sort_values(by = ['Year','Director'] , ascending=[False, True]).head(2)
# Out:
#        Film  Year         Actor    Director  Box Office  Budget  \
# 25  Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3
# 24  Skyfall  2012  Daniel Craig  Sam Mendes       943.5   170.2
#
#     Bond Actor Salary
# 25                NaN
# 24               14.5

# %%
# box plot of Budget and Box Office
bond[['Budget','Box Office']].plot(kind='bar', figsize=(14,5));
plt.xticks(bond.index, bond['Film']);

# %%
sample = pd.DataFrame({'A': [10,20,np.nan], 
                 'B' : [200,300,400],
                 'C' : [1000,2000,3000]})
sample
# Out:
#       A    B     C
# 0  10.0  200  1000
# 1  20.0  300  2000
# 2   NaN  400  3000

# %%
#sample['D']='test'
sample['D'] = sample['C']-sample['B']
sample
# Out:
#       A    B     C     D
# 0  10.0  200  1000   800
# 1  20.0  300  2000  1700
# 2   NaN  400  3000  2600

# %%
#Top 2 films with greatest ROI
bond['ROI'] = (bond['Box Office']-bond['Budget'])/bond['Budget']
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary        ROI
# 0        448.8     7.0                0.6  63.114286
# 1        543.8    12.6                1.6  42.158730
# 2        820.4    18.6                3.2  43.107527
# 3        848.1    41.9                4.7  19.241050
# 4        315.0    85.0                NaN   2.705882
# 5        514.2    59.9                4.4   7.584307
# 6        291.5    37.3                0.6   6.815013
# 7        442.5    34.7                5.8  11.752161
# 8        460.3    30.8                NaN  13.944805
# 9        334.0    27.7                NaN  11.057762
# 10       533.0    45.1                NaN  10.818182
# 11       535.0    91.5                NaN   4.846995
# 12       449.4    60.2                NaN   6.465116
# 13       380.0    86.0                NaN   3.418605
# 14       373.8    53.9                7.8   5.935065
# 15       275.2    54.5                9.1   4.049541
# 16       313.5    68.8                5.2   3.556686
# 17       250.9    56.7                7.9   3.425044
# 18       518.5    76.9                5.1   5.742523
# 19       463.2   133.9               10.0   2.459298
# 20       439.5   158.3               13.5   1.776374
# 21       465.4   154.2               17.9   2.018158
# 22       581.5   145.3                3.3   3.002065
# 23       514.2   181.4                8.1   1.834620
# 24       943.5   170.2               14.5   4.543478
# 25       726.7   206.3                NaN   2.522540

# %%
bond.sort_values(by=['ROI'], ascending=False).head(2)
# Out:
#          Film  Year         Actor       Director  Box Office  Budget  \
# 0      Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
# 2  Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#    Bond Actor Salary        ROI
# 0                0.6  63.114286
# 2                3.2  43.107527

# %%
# Find out outliers for Box Office
plt.figure(figsize=(15,4))
plt.boxplot(bond['Box Office'], vert=False)
plt.xticks(bond['Box Office'], bond['Film'], rotation=90);

# %%
bond['Box Office'].describe()
# Out:
# count     26.000000
# mean     491.611538
# std      176.740396
# min      250.900000
# 25%      375.350000
# 50%      461.750000
# 75%      534.500000
# max      943.500000
# Name: Box Office, dtype: float64

# %%
plt.boxplot(bond['Budget'], vert=False);

# %%
# Which films are outliers
bond.sort_values(by=['Box Office'], ascending=False).head(5)
# Out:
#              Film  Year         Actor         Director  Box Office  Budget  \
# 24        Skyfall  2012  Daniel Craig       Sam Mendes       943.5   170.2
# 3     Thunderball  1965  Sean Connery    Terence Young       848.1    41.9
# 2      Goldfinger  1964  Sean Connery     Guy Hamilton       820.4    18.6
# 25        Spectre  2015  Daniel Craig       Sam Mendes       726.7   206.3
# 22  Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#     Bond Actor Salary        ROI
# 24               14.5   4.543478
# 3                 4.7  19.241050
# 2                 3.2  43.107527
# 25                NaN   2.522540
# 22                3.3   3.002065

# %%
# Box Office > Q3 + 1.5*IQR
IQR  = np.percentile(bond['Box Office'],75)-np.percentile(bond['Box Office'],25)
UB = round(np.percentile(bond['Box Office'],75) + 1.5*IQR,2)
mask = bond['Box Office'] >  UB
bond[mask]
# Out:
#            Film  Year         Actor       Director  Box Office  Budget  \
# 2    Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
#
#     Bond Actor Salary        ROI
# 2                 3.2  43.107527
# 3                 4.7  19.241050
# 24               14.5   4.543478

# %%
# Box Office > Q3 + 1.5*IQR
bond_bo_info = bond['Box Office'].describe()
IQR  =bond_bo_info[6]-bond_bo_info[4]
UB = round(bond_bo_info[6] + 1.5*IQR,2)
mask = bond['Box Office'] >  UB
bond[mask]
# Out:
#            Film  Year         Actor       Director  Box Office  Budget  \
# 2    Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
# 3   Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# 24      Skyfall  2012  Daniel Craig     Sam Mendes       943.5   170.2
#
#     Bond Actor Salary        ROI
# 2                 3.2  43.107527
# 3                 4.7  19.241050
# 24               14.5   4.543478

# %%
# Over the years how has budget changed
# Draw a line chart for Years on x axis and Budget on y axis
plt.figure(figsize=(14,5))
plt.plot(bond['Year'], bond['Budget'], marker='*',ms=15,  
         color='red', ls = '-.',mec='blue')
plt.plot(bond['Year'], bond['Box Office'], marker='d',ms=10,  
         color='g', ls = '--',mec='blue')
plt.xticks(bond['Year'], rotation=90)
plt.xlabel("Year")
plt.ylabel("Budget")
plt.title("Year wise Budget")
plt.show()

# %%
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary        ROI
# 0        448.8     7.0                0.6  63.114286
# 1        543.8    12.6                1.6  42.158730
# 2        820.4    18.6                3.2  43.107527
# 3        848.1    41.9                4.7  19.241050
# 4        315.0    85.0                NaN   2.705882
# 5        514.2    59.9                4.4   7.584307
# 6        291.5    37.3                0.6   6.815013
# 7        442.5    34.7                5.8  11.752161
# 8        460.3    30.8                NaN  13.944805
# 9        334.0    27.7                NaN  11.057762
# 10       533.0    45.1                NaN  10.818182
# 11       535.0    91.5                NaN   4.846995
# 12       449.4    60.2                NaN   6.465116
# 13       380.0    86.0                NaN   3.418605
# 14       373.8    53.9                7.8   5.935065
# 15       275.2    54.5                9.1   4.049541
# 16       313.5    68.8                5.2   3.556686
# 17       250.9    56.7                7.9   3.425044
# 18       518.5    76.9                5.1   5.742523
# 19       463.2   133.9               10.0   2.459298
# 20       439.5   158.3               13.5   1.776374
# 21       465.4   154.2               17.9   2.018158
# 22       581.5   145.3                3.3   3.002065
# 23       514.2   181.4                8.1   1.834620
# 24       943.5   170.2               14.5   4.543478
# 25       726.7   206.3                NaN   2.522540

# %% [markdown]
# # ways to use index location
# df.iloc[rowslice][cols]
# df.iloc[[rowindex]][cols]
# df.iloc[[rowindex],[colindex]]
# df.iloc[rowslice, colslice]

# %%
# rename columns names
# here I am removing space from columns
bond.rename(columns = {"Bond Actor Salary" : "BondActorSalary", 
                       "Box Office" : "BoxOffice"}, 
            inplace = True)

# %%
bond.columns
# Out:
# Index(['Film', 'Year', 'Actor', 'Director', 'BoxOffice', 'Budget',
#        'BondActorSalary', 'ROI'],
#       dtype='object')

# %%
bond['Film'].apply(len)
# Out:
# 0      6
# 1     21
# 2     10
# 3     11
# 4     13
# 5     19
# 6     31
# 7     20
# 8     16
# 9     27
# 10    20
# 11     9
# 12    18
# 13    21
# 14     9
# 15    16
# 16    20
# 17    15
# 18     9
# 19    19
# 20    23
# 21    15
# 22    13
# 23    17
# 24     7
# 25     7
# Name: Film, dtype: int64

# %%
def myfunc(r):
    if r.Actor == "Pierce Brosnan":        
        return "The best"
    elif r.Actor == "Roger Moore" and r.Budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"

# %%
## Select only Roger Moore films
bond['Remarks'] = bond.apply(myfunc, axis=1)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     BoxOffice  Budget  BondActorSalary        ROI         Remarks
# 0       448.8     7.0              0.6  63.114286  I have no clue
# 1       543.8    12.6              1.6  42.158730  I have no clue
# 2       820.4    18.6              3.2  43.107527  I have no clue
# 3       848.1    41.9              4.7  19.241050  I have no clue
# 4       315.0    85.0              NaN   2.705882  I have no clue
# 5       514.2    59.9              4.4   7.584307  I have no clue
# 6       291.5    37.3              0.6   6.815013  I have no clue
# 7       442.5    34.7              5.8  11.752161  I have no clue
# 8       460.3    30.8              NaN  13.944805  I have no clue
# 9       334.0    27.7              NaN  11.057762  I have no clue
# 10      533.0    45.1              NaN  10.818182       Enjoyable
# 11      535.0    91.5              NaN   4.846995       Enjoyable
# 12      449.4    60.2              NaN   6.465116       Enjoyable
# 13      380.0    86.0              NaN   3.418605  I have no clue
# 14      373.8    53.9              7.8   5.935065       Enjoyable
# 15      275.2    54.5              9.1   4.049541       Enjoyable
# 16      313.5    68.8              5.2   3.556686  I have no clue
# 17      250.9    56.7              7.9   3.425044  I have no clue
# 18      518.5    76.9              5.1   5.742523        The best
# 19      463.2   133.9             10.0   2.459298        The best
# 20      439.5   158.3             13.5   1.776374        The best
# 21      465.4   154.2             17.9   2.018158        The best
# 22      581.5   145.3              3.3   3.002065  I have no clue
# 23      514.2   181.4              8.1   1.834620  I have no clue
# 24      943.5   170.2             14.5   4.543478  I have no clue
# 25      726.7   206.3              NaN   2.522540  I have no clue

# %%
## Select only Roger Moore films
bond['Remarks'] = bond.apply(lambda r: "The best" if r.Actor == "Pierce Brosnan" else  "Enjoyable" if (r.Actor == "Roger Moore" and r.Budget > 40) else "I have no clue", axis=1)
bond.head(15)
# Out:
#                                Film  Year           Actor        Director  \
# 0                            Dr. No  1962    Sean Connery   Terence Young
# 1             From Russia with Love  1963    Sean Connery   Terence Young
# 2                        Goldfinger  1964    Sean Connery    Guy Hamilton
# 3                       Thunderball  1965    Sean Connery   Terence Young
# 4                     Casino Royale  1967     David Niven      Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery   Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery    Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore    Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore    Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore   Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore   Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore       John Glen
# 13            Never Say Never Again  1983    Sean Connery  Irvin Kershner
# 14                        Octopussy  1983     Roger Moore       John Glen
#
#     BoxOffice  Budget  BondActorSalary        ROI         Remarks
# 0       448.8     7.0              0.6  63.114286  I have no clue
# 1       543.8    12.6              1.6  42.158730  I have no clue
# 2       820.4    18.6              3.2  43.107527  I have no clue
# 3       848.1    41.9              4.7  19.241050  I have no clue
# 4       315.0    85.0              NaN   2.705882  I have no clue
# 5       514.2    59.9              4.4   7.584307  I have no clue
# 6       291.5    37.3              0.6   6.815013  I have no clue
# 7       442.5    34.7              5.8  11.752161  I have no clue
# 8       460.3    30.8              NaN  13.944805  I have no clue
# 9       334.0    27.7              NaN  11.057762  I have no clue
# 10      533.0    45.1              NaN  10.818182       Enjoyable
# 11      535.0    91.5              NaN   4.846995       Enjoyable
# 12      449.4    60.2              NaN   6.465116       Enjoyable
# 13      380.0    86.0              NaN   3.418605  I have no clue
# 14      373.8    53.9              7.8   5.935065       Enjoyable

# %%
## Select only Roger Moore films
bond['Remarks'] = bond.apply(myfunc, axis=1)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     BoxOffice  Budget  BondActorSalary        ROI         Remarks
# 0       448.8     7.0              0.6  63.114286  I have no clue
# 1       543.8    12.6              1.6  42.158730  I have no clue
# 2       820.4    18.6              3.2  43.107527  I have no clue
# 3       848.1    41.9              4.7  19.241050  I have no clue
# 4       315.0    85.0              NaN   2.705882  I have no clue
# 5       514.2    59.9              4.4   7.584307  I have no clue
# 6       291.5    37.3              0.6   6.815013  I have no clue
# 7       442.5    34.7              5.8  11.752161  I have no clue
# 8       460.3    30.8              NaN  13.944805  I have no clue
# 9       334.0    27.7              NaN  11.057762  I have no clue
# 10      533.0    45.1              NaN  10.818182       Enjoyable
# 11      535.0    91.5              NaN   4.846995       Enjoyable
# 12      449.4    60.2              NaN   6.465116       Enjoyable
# 13      380.0    86.0              NaN   3.418605  I have no clue
# 14      373.8    53.9              7.8   5.935065       Enjoyable
# 15      275.2    54.5              9.1   4.049541       Enjoyable
# 16      313.5    68.8              5.2   3.556686  I have no clue
# 17      250.9    56.7              7.9   3.425044  I have no clue
# 18      518.5    76.9              5.1   5.742523        The best
# 19      463.2   133.9             10.0   2.459298        The best
# 20      439.5   158.3             13.5   1.776374        The best
# 21      465.4   154.2             17.9   2.018158        The best
# 22      581.5   145.3              3.3   3.002065  I have no clue
# 23      514.2   181.4              8.1   1.834620  I have no clue
# 24      943.5   170.2             14.5   4.543478  I have no clue
# 25      726.7   206.3              NaN   2.522540  I have no clue

# %% [markdown]
# Add a column Remarks and use following logic to add values
# if actor == "Pierce Brosnan"        "The best"
# actor == "Roger Moore" and budget > 40
#         "Enjoyable"
# "I have no clue"

# %%
c = np.array([[10,51,55], [56,5,2]])

# %%
np.where(c>50, 100, -100)
# Out:
# array([[-100,  100,  100],
#        [ 100, -100, -100]])

# %%
# groupby and treatment of NA values

# %%
sample
# Out:
#       A    B     C     D
# 0  10.0  200  1000   800
# 1  20.0  300  2000  1700
# 2   NaN  400  3000  2600

# %%
sample.dropna()
# drops entire rows even if one column has NA values
# wherever NA values
# Out:
#       A    B     C     D
# 0  10.0  200  1000   800
# 1  20.0  300  2000  1700

# %%
sample.iloc[[1],[0]] = np.nan

# %%
sample
# Out:
#       A    B     C     D
# 0  10.0  200  1000   800
# 1   NaN  300  2000  1700
# 2   NaN  400  3000  2600

# %%
sample.dropna(axis=1, thresh=2)
# Require that many non-NA values.
# drops column where any value is NA
# Out:
#      B     C     D
# 0  200  1000   800
# 1  300  2000  1700
# 2  400  3000  2600

# %%
sample.fillna(value=sample['A'].mean())
# Out:
#       A    B     C     D
# 0  10.0  200  1000   800
# 1  10.0  300  2000  1700
# 2  10.0  400  3000  2600

# %%
# Create dataframe
data = {'Company':['RIL','RIL','TCS','TCS','ICICI','ICICI'],
       'Person':['Anushka','Ramdeo','Archana','Vineeta','Ritika','Sapna'],
       'Sales':[200,120,340,124,243,350]}
co_df =  pd.DataFrame(data)

# %%
co_df
# Out:
#   Company   Person  Sales
# 0     RIL  Anushka    200
# 1     RIL   Ramdeo    120
# 2     TCS  Archana    340
# 3     TCS  Vineeta    124
# 4   ICICI   Ritika    243
# 5   ICICI    Sapna    350

# %%
by_comp = co_df.groupby('Company')
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# ICICI     2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# RIL       2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# TCS       2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.sum()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15392\1130347586.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.sum()
#          Sales
# Company
# ICICI      593
# RIL        320
# TCS        464

# %%
by_comp.groups
# Out:
# {'ICICI': [4, 5], 'RIL': [0, 1], 'TCS': [2, 3]}

# %%
# Apply this on bond['Actor'] column
# How much has each Actor achieved on Box Office and How much was total salary

# %%
grpActor = bond.groupby('Actor')

# %%
grpActor[['BoxOffice', 'BondActorSalary']].sum()
# Out:
#                 BoxOffice  BondActorSalary
# Actor
# Daniel Craig       2765.9             25.9
# David Niven         315.0              0.0
# George Lazenby      291.5              0.6
# Pierce Brosnan     1886.6             46.5
# Roger Moore        2960.7             16.9
# Sean Connery       3997.8             20.3
# Timothy Dalton      564.4             13.1

# %%
grpActor[['BoxOffice', 'BondActorSalary']].mean()
# Out:
#                  BoxOffice  BondActorSalary
# Actor
# Daniel Craig    691.475000         8.633333
# David Niven     315.000000              NaN
# George Lazenby  291.500000         0.600000
# Pierce Brosnan  471.650000        11.625000
# Roger Moore     422.957143         8.450000
# Sean Connery    571.114286         3.383333
# Timothy Dalton  282.200000         6.550000

# %%
ax = bond.boxplot(column= 'BoxOffice', by='Actor', figsize=(15,5))
ax.set_title("")
ax.set_ylabel("Revenue")
ax.set_xlabel("Actor")
plt.suptitle("Revenue by Actor")
plt.grid(True)
plt.show()
